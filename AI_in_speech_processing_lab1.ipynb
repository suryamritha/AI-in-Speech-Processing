# %% [markdown]
# # SURYAMRITHA M

# %% [markdown]
# # BL.EN.U4AIE21126

# %% [markdown]
# A1. Load the recorded speech file into your python workspace. Once loaded, plot the graph for the speech signal. You may use the below code from librosa as a reference.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

from glob import glob

import librosa
import librosa.display
import IPython.display as ipd
from IPython.display import Audio, display

from itertools import cycle

sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %%
audio_file =  r"C:\Users\surya\Downloads\speech_process.wav"
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load(audio_file)
librosa.display.waveshow(y)

# %% [markdown]
# A2. Observe the length & magnitude range of the signal from the plot. Observing the plot, relate to the spoken words and silence between the words.

# %%
duration = len(y) / sr  # Duration in seconds
print(f"Duration of the audio: {duration:.2f} seconds")
print(f"Magnitude range: {y.min()} to {y.max()}")
# Out:
# Duration of the audio: 3.86 seconds
# Magnitude range: -0.031673405319452286 to 0.02965572662651539

# %% [markdown]
# A3. Take a small segment of the signal and play it.

# %%
y, sr = librosa.load(audio_file , offset=0.0, duration=1.0)
y
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.00642845,
#        -0.00981379, -0.01274568], dtype=float32)

# %%
audio1 = Audio(y, rate=sr)
display(audio1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# A4. Play around with your recorded speech signal for various segments. Understand the nature of the signal. Also observe with abruptly segmented speech, how the perception of that speech is affected.

# %%
y, sr = librosa.load(audio_file , offset=1.0, duration=1.0)
audio2 = Audio(y, rate=sr)
display(audio2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load(audio_file , offset=2.0, duration=3.0)
audio2 = Audio(y, rate=sr)
display(audio2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
